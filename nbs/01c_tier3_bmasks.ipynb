# %% [markdown]
# # Tier 3 binary masks

# %% [markdown]
# Binary masks are also 'building masks'.  Technically, 'building' is just one of the types of features in the dataset, but let's just call all features buildings.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#export
from xview2comp.nb_01b import *
from fastai.vision import *
from fastai.utils.collect_env import *

# %% [markdown]
# ### Generate building masks for Tier 3 data set

# %%
SOURCE = Path('data/tier3/images/')

# %%
fnames = get_image_files(SOURCE)
len(fnames), fnames[:3]
# Out:
# (12738,
#  [PosixPath('data/tier3/images/tuscaloosa-tornado_00000009_pre_disaster.png'),
#   PosixPath('data/tier3/images/portugal-wildfire_00001389_pre_disaster.png'),
#   PosixPath('data/tier3/images/pinery-bushfire_00000250_pre_disaster.png')])

# %%
npreimgs = pre_img_fpaths(fnames)

# %%
len(npreimgs)
# Out:
# 6369

# %%
path_bmasks = Path('data/tier3/binarymasks')

# %%
os.makedirs(path_bmasks, exist_ok=True)

# %%
# %%time
generate_pre_binarymasks(npreimgs)
# Out:
# CPU times: user 6min 36s, sys: 1.59 s, total: 6min 38s
# Wall time: 6min 37s

# %%
len(path_bmasks.ls())
# Out:
# 6369

# %%
idx = 709

nimg = npreimgs[idx]
nmask = img2bmask_fpath(nimg)
img, mask = open_image(nimg), open_mask(nmask)
_, ax = plt.subplots(figsize=(6, 6))
img.show(ax)
mask.show(ax, alpha=.5, cmap=CMAP, vmax=4)

# %% [markdown]
# # - fin
